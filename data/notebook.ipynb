# %%
import numpy  as np
import pandas as pd
import seaborn as sns

# %%
npl= pd.read_csv("/home/ujjwal/projects/NPL-Fantasty_API/data/raw/NPL matches.csv")
ball_2024= pd.read_csv("/home/ujjwal/projects/NPL-Fantasty_API/data/raw/NPL-2024.csv")
ball_2025= pd.read_csv("/home/ujjwal/projects/NPL-Fantasty_API/data/raw/NPL-2025.csv")

# %% [markdown]
# - NPL matches.csv includes 27 columns of match details, such as the date, venue, teams, toss winner, toss decision, result, winner, overs played, MVP, and more.
#
# - NPL-2024.csv and NPL-2025.csv contains 20 columns detailing every ball of the match, including inning, batting team, bowling team, bowler, batter, non-striker, shot direction, batsman runs, total runs, and more.

# %%
npl.shape , ball_2024.shape , ball_2025.shape
# Out:
# ((64, 29), (7485, 20), (7439, 20))
